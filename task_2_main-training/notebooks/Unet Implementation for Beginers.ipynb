# %%
from tensorflow.keras.utils import normalize
import os
import cv2
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.optimizers import Adam
import glob

# %%
# Path to image and masks
image_dir = "/content/drive/MyDrive/HOT_OSM/train/images"
mask_dir = "/content/drive/MyDrive/HOT_OSM/train/masks"
val_image_dir = "/content/drive/MyDrive/HOT_OSM/validation/images"
val_mask_dir = "/content/drive/MyDrive/HOT_OSM/validation/masks"

# %%
# using the glob.glob function to get the names of the images
image_names = glob.glob(image_dir + "/*png")
print(image_names)
# Out:
# ['/content/drive/MyDrive/HOT_OSM/train/images/42.png', '/content/drive/MyDrive/HOT_OSM/train/images/96.png', '/content/drive/MyDrive/HOT_OSM/train/images/22.png', '/content/drive/MyDrive/HOT_OSM/train/images/120.png', '/content/drive/MyDrive/HOT_OSM/train/images/143.png', '/content/drive/MyDrive/HOT_OSM/train/images/32.png', '/content/drive/MyDrive/HOT_OSM/train/images/8.png', '/content/drive/MyDrive/HOT_OSM/train/images/80.png', '/content/drive/MyDrive/HOT_OSM/train/images/141.png', '/content/drive/MyDrive/HOT_OSM/train/images/4.png', '/content/drive/MyDrive/HOT_OSM/train/images/89.png', '/content/drive/MyDrive/HOT_OSM/train/images/72.png', '/content/drive/MyDrive/HOT_OSM/train/images/101.png', '/content/drive/MyDrive/HOT_OSM/train/images/2.png', '/content/drive/MyDrive/HOT_OSM/train/images/99.png', '/content/drive/MyDrive/HOT_OSM/train/images/54.png', '/content/drive/MyDrive/HOT_OSM/train/images/115.png', '/content/drive/MyDrive/HOT_OSM/train/images/63.png', '/content/drive/MyDrive/HOT_OSM/train/images/132.png', '/content/drive/MyDrive/HOT_OSM/train/images/125.png', '/content/drive/MyDrive/HOT_OSM/train/images/119.png', '/content/drive/MyDrive/HOT_OSM/train/images/24.png', '/content/drive/MyDrive/HOT_OSM/train/images/84.png', '/content/drive/MyDrive/HOT_OSM/train/images/26.png', '/content/drive/MyDrive/HOT_OSM/train/images/81.png', '/content/drive/MyDrive/HOT_OSM/train/images/51.png', '/content/drive/MyDrive/HOT_OSM/train/images/60.png', '/content/drive/MyDrive/HOT_OSM/train/images/130.png', '/content/drive/MyDrive/HOT_OSM/train/images/19.png', '/content/drive/MyDrive/HOT_OSM/train/images/112.png', '/content/drive/MyDrive/HOT_OSM/train/images/1.png', '/content/drive/MyDrive/HOT_OSM/train/images/10.png', '/content/drive/MyDrive/HOT_OSM/train/images/127.png', '/content/drive/MyDrive/HOT_OSM/train/images/44.png', '/content/drive/MyDrive/HOT_OSM/train/images/53.png', '/content/drive/MyDrive/HOT_OSM/train/images/16.png', '/content/drive/MyDrive/HOT_OSM/train/images/86.png', '/content/drive/MyDrive/HOT_OSM/train/images/25.png', '/content/drive/MyDrive/HOT_OSM/train/images/57.png', '/content/drive/MyDrive/HOT_OSM/train/images/98.png', '/content/drive/MyDrive/HOT_OSM/train/images/110.png', '/content/drive/MyDrive/HOT_OSM/train/images/45.png', '/content/drive/MyDrive/HOT_OSM/train/images/56.png', '/content/drive/MyDrive/HOT_OSM/train/images/0.png', '/content/drive/MyDrive/HOT_OSM/train/images/117.png', '/content/drive/MyDrive/HOT_OSM/train/images/18.png', '/content/drive/MyDrive/HOT_OSM/train/images/7.png', '/content/drive/MyDrive/HOT_OSM/train/images/142.png', '/content/drive/MyDrive/HOT_OSM/train/images/77.png', '/content/drive/MyDrive/HOT_OSM/train/images/136.png', '/content/drive/MyDrive/HOT_OSM/train/images/30.png', '/content/drive/MyDrive/HOT_OSM/train/images/43.png', '/content/drive/MyDrive/HOT_OSM/train/images/29.png', '/content/drive/MyDrive/HOT_OSM/train/images/128.png', '/content/drive/MyDrive/HOT_OSM/train/images/48.png', '/content/drive/MyDrive/HOT_OSM/train/images/76.png', '/content/drive/MyDrive/HOT_OSM/train/images/69.png', '/content/drive/MyDrive/HOT_OSM/train/images/6.png', '/content/drive/MyDrive/HOT_OSM/train/images/52.png', '/content/drive/MyDrive/HOT_OSM/train/images/67.png', '/content/drive/MyDrive/HOT_OSM/train/images/15.png', '/content/drive/MyDrive/HOT_OSM/train/images/23.png', '/content/drive/MyDrive/HOT_OSM/train/images/138.png', '/content/drive/MyDrive/HOT_OSM/train/images/107.png', '/content/drive/MyDrive/HOT_OSM/train/images/91.png', '/content/drive/MyDrive/HOT_OSM/train/images/140.png', '/content/drive/MyDrive/HOT_OSM/train/images/9.png', '/content/drive/MyDrive/HOT_OSM/train/images/124.png', '/content/drive/MyDrive/HOT_OSM/train/images/121.png', '/content/drive/MyDrive/HOT_OSM/train/images/75.png', '/content/drive/MyDrive/HOT_OSM/train/images/66.png', '/content/drive/MyDrive/HOT_OSM/train/images/144.png', '/content/drive/MyDrive/HOT_OSM/train/images/17.png', '/content/drive/MyDrive/HOT_OSM/train/image ...

# %%
# sorting the images according to the names
image_names.sort()
print(image_names)
# Out:
# ['/content/drive/MyDrive/HOT_OSM/train/images/0.png', '/content/drive/MyDrive/HOT_OSM/train/images/1.png', '/content/drive/MyDrive/HOT_OSM/train/images/10.png', '/content/drive/MyDrive/HOT_OSM/train/images/100.png', '/content/drive/MyDrive/HOT_OSM/train/images/101.png', '/content/drive/MyDrive/HOT_OSM/train/images/102.png', '/content/drive/MyDrive/HOT_OSM/train/images/103.png', '/content/drive/MyDrive/HOT_OSM/train/images/104.png', '/content/drive/MyDrive/HOT_OSM/train/images/105.png', '/content/drive/MyDrive/HOT_OSM/train/images/106.png', '/content/drive/MyDrive/HOT_OSM/train/images/107.png', '/content/drive/MyDrive/HOT_OSM/train/images/108.png', '/content/drive/MyDrive/HOT_OSM/train/images/109.png', '/content/drive/MyDrive/HOT_OSM/train/images/11.png', '/content/drive/MyDrive/HOT_OSM/train/images/110.png', '/content/drive/MyDrive/HOT_OSM/train/images/111.png', '/content/drive/MyDrive/HOT_OSM/train/images/112.png', '/content/drive/MyDrive/HOT_OSM/train/images/113.png', '/content/drive/MyDrive/HOT_OSM/train/images/114.png', '/content/drive/MyDrive/HOT_OSM/train/images/115.png', '/content/drive/MyDrive/HOT_OSM/train/images/116.png', '/content/drive/MyDrive/HOT_OSM/train/images/117.png', '/content/drive/MyDrive/HOT_OSM/train/images/118.png', '/content/drive/MyDrive/HOT_OSM/train/images/119.png', '/content/drive/MyDrive/HOT_OSM/train/images/12.png', '/content/drive/MyDrive/HOT_OSM/train/images/120.png', '/content/drive/MyDrive/HOT_OSM/train/images/121.png', '/content/drive/MyDrive/HOT_OSM/train/images/122.png', '/content/drive/MyDrive/HOT_OSM/train/images/123.png', '/content/drive/MyDrive/HOT_OSM/train/images/124.png', '/content/drive/MyDrive/HOT_OSM/train/images/125.png', '/content/drive/MyDrive/HOT_OSM/train/images/126.png', '/content/drive/MyDrive/HOT_OSM/train/images/127.png', '/content/drive/MyDrive/HOT_OSM/train/images/128.png', '/content/drive/MyDrive/HOT_OSM/train/images/129.png', '/content/drive/MyDrive/HOT_OSM/train/images/13.png', '/content/drive/MyDrive/HOT_OSM/train/images/130.png', '/content/drive/MyDrive/HOT_OSM/train/images/131.png', '/content/drive/MyDrive/HOT_OSM/train/images/132.png', '/content/drive/MyDrive/HOT_OSM/train/images/133.png', '/content/drive/MyDrive/HOT_OSM/train/images/134.png', '/content/drive/MyDrive/HOT_OSM/train/images/135.png', '/content/drive/MyDrive/HOT_OSM/train/images/136.png', '/content/drive/MyDrive/HOT_OSM/train/images/137.png', '/content/drive/MyDrive/HOT_OSM/train/images/138.png', '/content/drive/MyDrive/HOT_OSM/train/images/139.png', '/content/drive/MyDrive/HOT_OSM/train/images/14.png', '/content/drive/MyDrive/HOT_OSM/train/images/140.png', '/content/drive/MyDrive/HOT_OSM/train/images/141.png', '/content/drive/MyDrive/HOT_OSM/train/images/142.png', '/content/drive/MyDrive/HOT_OSM/train/images/143.png', '/content/drive/MyDrive/HOT_OSM/train/images/144.png', '/content/drive/MyDrive/HOT_OSM/train/images/15.png', '/content/drive/MyDrive/HOT_OSM/train/images/16.png', '/content/drive/MyDrive/HOT_OSM/train/images/17.png', '/content/drive/MyDrive/HOT_OSM/train/images/18.png', '/content/drive/MyDrive/HOT_OSM/train/images/19.png', '/content/drive/MyDrive/HOT_OSM/train/images/2.png', '/content/drive/MyDrive/HOT_OSM/train/images/20.png', '/content/drive/MyDrive/HOT_OSM/train/images/21.png', '/content/drive/MyDrive/HOT_OSM/train/images/22.png', '/content/drive/MyDrive/HOT_OSM/train/images/23.png', '/content/drive/MyDrive/HOT_OSM/train/images/24.png', '/content/drive/MyDrive/HOT_OSM/train/images/25.png', '/content/drive/MyDrive/HOT_OSM/train/images/26.png', '/content/drive/MyDrive/HOT_OSM/train/images/27.png', '/content/drive/MyDrive/HOT_OSM/train/images/28.png', '/content/drive/MyDrive/HOT_OSM/train/images/29.png', '/content/drive/MyDrive/HOT_OSM/train/images/3.png', '/content/drive/MyDrive/HOT_OSM/train/images/30.png', '/content/drive/MyDrive/HOT_OSM/train/images/31.png', '/content/drive/MyDrive/HOT_OSM/train/images/32.png', '/content/drive/MyDrive/HOT_OSM/train/images/33.png', '/content/drive/ ...

# %%
# We use the cv2.imread functino and a list comprehension to get the images in a specific order.
images = [cv2.imread(img, 0) for img in image_names]

# %%
image_dataset = np.array(images)
image_dataset = np.expand_dims(image_dataset, axis=3)

# %%
# We will read and sort the masks, the same way we did the images.
mask_names = glob.glob(mask_dir + "/*png")
mask_names.sort()
masks = [cv2.imread(mask, 0) for mask in mask_names]
mask_dataset = np.array(masks)
mask_dataset = np.expand_dims(mask_dataset, axis=3)

# %%
print("Image data shape is: ", image_dataset.shape)
print("Mask data shape is: ", mask_dataset.shape)
print("Max pixel value in image is: ", image_dataset.max())
print("Labels in the mask are : ", np.unique(mask_dataset))
# Out:
# Image data shape is:  (145, 256, 256, 1)
# Mask data shape is:  (145, 256, 256, 1)
# Max pixel value in image is:  255
# Labels in the mask are :  [  0 255]

# %%
# Normalize images
image_dataset = image_dataset / 255
mask_dataset = mask_dataset / 255

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    image_dataset, mask_dataset, test_size=0.10, random_state=42
)

# %%
import random

image_number = random.randint(0, len(image_dataset) - 1)
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number, :, :, 0])
plt.subplot(122)
plt.imshow(mask_dataset[image_number, :, :, 0])
plt.show()

# %%
# Building Unet by dividing encoder and decoder into blocks

from keras.models import Model
from keras.layers import (
    Input,
    Conv2D,
    MaxPooling2D,
    UpSampling2D,
    concatenate,
    Conv2DTranspose,
    BatchNormalization,
    Dropout,
    Lambda,
)
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate


def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)  # Not in the original network.
    x = Activation("swish")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)  # Not in the original network
    x = Activation("swish")(x)

    return x


# Encoder block: Conv block followed by maxpooling


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p


# Decoder block
# skip features gets input from encoder for concatenation


def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


# Build Unet using the blocks
def build_unet(input_shape, n_classes):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)  # Bridge

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    if n_classes == 1:  # Binary
        activation = "sigmoid"
    else:
        activation = "softmax"

    outputs = Conv2D(n_classes, 1, padding="same", activation=activation)(
        d4
    )  # Change the activation based on n_classes
    print(activation)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
IMG_HEIGHT = image_dataset.shape[1]
IMG_WIDTH = image_dataset.shape[2]
IMG_CHANNELS = image_dataset.shape[3]

input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

# %%
model = build_unet(input_shape, n_classes=1)
model.compile(
    optimizer=Adam(learning_rate=1e-3), loss="binary_crossentropy", metrics=["accuracy"]
)
model.summary()
# Out:
# sigmoid
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 64  640         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 256, 256, 64  256        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 64  36928       ['activation_20[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 256, 256, 64  256        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64  0          ['activation_21[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 12  512        ['conv2d_23[0][0]']
#  ormalization)                  8)
#
#  activation_22 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_22[0][0]']
#                                 8)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 12  147584      ['activation_22[0][0]']
#                                 8)
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 12  512        ['conv2d_24[0][0]']
#  ormalization)                  8)
#
#  activation_23 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_23[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 256)  295168      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_25[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_27[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  activation_28 (Activation)     (None, 16, 16, 1024  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 1024  9438208     ['activation_28[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_30[0][0]']
#  ormalization)                  )
#
#  activation_29 (Activation)     (None, 16, 16, 1024  0           ['batch_normalization_29[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 512)  2097664    ['activation_29[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_31[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_33[0][0]']
#  spose)                         8)
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'activation_23[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_34 (BatchN  (None, 128, 128, 12  512        ['conv2d_35[0][0]']
#  ormalization)                  8)
#
#  activation_34 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_34[0][0]']
#                                 8)
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 12  147584      ['activation_34[0][0]']
#                                 8)
#
#  batch_normalization_35 (BatchN  (None, 128, 128, 12  512        ['conv2d_36[0][0]']
#  ormalization)                  8)
#
#  activation_35 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_35[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_35[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'activation_21[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 256, 256, 64  256        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 256, 256, 64  36928       ['activation_36[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 256, 256, 64  256        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  activation_37 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_37[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 1)  65          ['activation_37[0][0]']
#
# ==================================================================================================
# Total params: 31,054,145
# Trainable params: 31,042,369
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size=7,
    verbose=1,
    epochs=100,
    validation_data=(X_test, y_test),
    shuffle=False,
)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 34s 868ms/step - loss: 0.4884 - accuracy: 0.8125 - val_loss: 0.7929 - val_accuracy: 0.5681
# Epoch 2/100
# 19/19 [==============================] - 10s 537ms/step - loss: 0.3842 - accuracy: 0.8559 - val_loss: 0.3932 - val_accuracy: 0.9114
# Epoch 3/100
# 19/19 [==============================] - 10s 528ms/step - loss: 0.3561 - accuracy: 0.8553 - val_loss: 0.3455 - val_accuracy: 0.9192
# Epoch 4/100
# 19/19 [==============================] - 10s 532ms/step - loss: 0.3492 - accuracy: 0.8550 - val_loss: 14.4819 - val_accuracy: 0.1281
# Epoch 5/100
# 19/19 [==============================] - 10s 538ms/step - loss: 0.3478 - accuracy: 0.8531 - val_loss: 479.5581 - val_accuracy: 0.0925
# Epoch 6/100
# 19/19 [==============================] - 10s 540ms/step - loss: 0.3455 - accuracy: 0.8552 - val_loss: 0.8963 - val_accuracy: 0.9171
# Epoch 7/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.3331 - accuracy: 0.8562 - val_loss: 1.6642 - val_accuracy: 0.0963
# Epoch 8/100
# 19/19 [==============================] - 10s 532ms/step - loss: 0.3292 - accuracy: 0.8603 - val_loss: 0.2980 - val_accuracy: 0.9184
# Epoch 9/100
# 19/19 [==============================] - 10s 531ms/step - loss: 0.3201 - accuracy: 0.8640 - val_loss: 0.3271 - val_accuracy: 0.9192
# Epoch 10/100
# 19/19 [==============================] - 10s 531ms/step - loss: 0.3184 - accuracy: 0.8628 - val_loss: 0.3887 - val_accuracy: 0.9175
# Epoch 11/100
# 19/19 [==============================] - 10s 532ms/step - loss: 0.3091 - accuracy: 0.8650 - val_loss: 0.4125 - val_accuracy: 0.9192
# Epoch 12/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.3045 - accuracy: 0.8637 - val_loss: 0.7575 - val_accuracy: 0.2854
# Epoch 13/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.3028 - accuracy: 0.8655 - val_loss: 0.4293 - val_accuracy: 0.9149
# Epoch 14/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2991 - accuracy: 0.8706 - val_loss: 0.6676 - val_accuracy: 0.4777
# Epoch 15/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2980 - accuracy: 0.8678 - val_loss: 0.3822 - val_accuracy: 0.9192
# Epoch 16/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.3002 - accuracy: 0.8660 - val_loss: 0.8540 - val_accuracy: 0.1932
# Epoch 17/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.2967 - accuracy: 0.8684 - val_loss: 0.3207 - val_accuracy: 0.9178
# Epoch 18/100
# 19/19 [==============================] - 10s 551ms/step - loss: 0.2883 - accuracy: 0.8707 - val_loss: 0.3142 - val_accuracy: 0.9191
# Epoch 19/100
# 19/19 [==============================] - 10s 537ms/step - loss: 0.2809 - accuracy: 0.8763 - val_loss: 0.3680 - val_accuracy: 0.9173
# Epoch 20/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.2832 - accuracy: 0.8783 - val_loss: 0.3530 - val_accuracy: 0.9175
# Epoch 21/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.2902 - accuracy: 0.8770 - val_loss: 0.2906 - val_accuracy: 0.9172
# Epoch 22/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.2823 - accuracy: 0.8734 - val_loss: 0.3716 - val_accuracy: 0.9192
# Epoch 23/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2885 - accuracy: 0.8749 - val_loss: 0.2843 - val_accuracy: 0.9176
# Epoch 24/100
# 19/19 [==============================] - 10s 551ms/step - loss: 0.2797 - accuracy: 0.8750 - val_loss: 0.3120 - val_accuracy: 0.9046
# Epoch 25/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2741 - accuracy: 0.8804 - val_loss: 0.5219 - val_accuracy: 0.7630
# Epoch 26/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2763 - accuracy: 0.8785 - val_loss: 0.3003 - val_accuracy: 0.8782
# Epoch 27/100
# 19/19 [==============================] - 10s 538ms/step - loss: 0.2649 - accuracy: 0.8847 - val_loss: 0.2685 - val_accuracy: 0.9124
# Epoch 28/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.2586 - accuracy: 0.8873 - val_loss: 0.4874 - val_accuracy: 0.7595
# Epoch 29/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2496 - accuracy: 0.8917 - val_loss: 0.3173 - val_accuracy: 0.8969
# Epoch 30/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2446 - accuracy: 0.8943 - val_loss: 0.2952 - val_accuracy: 0.8957
# Epoch 31/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.2498 - accuracy: 0.8910 - val_loss: 0.2651 - val_accuracy: 0.8925
# Epoch 32/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.2484 - accuracy: 0.8934 - val_loss: 0.2875 - val_accuracy: 0.8720
# Epoch 33/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2461 - accuracy: 0.8953 - val_loss: 0.3131 - val_accuracy: 0.8446
# Epoch 34/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.2411 - accuracy: 0.8951 - val_loss: 0.2932 - val_accuracy: 0.8826
# Epoch 35/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2560 - accuracy: 0.8896 - val_loss: 0.7949 - val_accuracy: 0.4318
# Epoch 36/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.2551 - accuracy: 0.8905 - val_loss: 0.2988 - val_accuracy: 0.8577
# Epoch 37/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.2396 - accuracy: 0.8965 - val_loss: 0.2876 - val_accuracy: 0.8764
# Epoch 38/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.2345 - accuracy: 0.8980 - val_loss: 0.2308 - val_accuracy: 0.9092
# Epoch 39/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.2306 - accuracy: 0.8992 - val_loss: 0.2459 - val_accuracy: 0.8889
# Epoch 40/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2206 - accuracy: 0.9048 - val_loss: 0.2620 - val_accuracy: 0.9074
# Epoch 41/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.2214 - accuracy: 0.9057 - val_loss: 0.4260 - val_accuracy: 0.8017
# Epoch 42/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.2161 - accuracy: 0.9079 - val_loss: 0.2532 - val_accuracy: 0.8738
# Epoch 43/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.2121 - accuracy: 0.9108 - val_loss: 0.2589 - val_accuracy: 0.9140
# Epoch 44/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.2059 - accuracy: 0.9149 - val_loss: 0.2704 - val_accuracy: 0.9095
# Epoch 45/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.1998 - accuracy: 0.9148 - val_loss: 0.2339 - val_accuracy: 0.9049
# Epoch 46/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.1875 - accuracy: 0.9216 - val_loss: 0.2889 - val_accuracy: 0.9137
# Epoch 47/100
# 19/19 [==============================] - 10s 537ms/step - loss: 0.1819 - accuracy: 0.9248 - val_loss: 0.2930 - val_accuracy: 0.9134
# Epoch 48/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.1847 - accuracy: 0.9238 - val_loss: 0.2453 - val_accuracy: 0.9060
# Epoch 49/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.1808 - accuracy: 0.9246 - val_loss: 0.2687 - val_accuracy: 0.9090
# Epoch 50/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.1700 - accuracy: 0.9296 - val_loss: 0.3155 - val_accuracy: 0.8996
# Epoch 51/100
# 19/19 [==============================] - 10s 548ms/step - loss: 0.1791 - accuracy: 0.9251 - val_loss: 0.3009 - val_accuracy: 0.9121
# Epoch 52/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.2051 - accuracy: 0.9136 - val_loss: 0.3913 - val_accuracy: 0.8039
# Epoch 53/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.1889 - accuracy: 0.9214 - val_loss: 0.2822 - val_accuracy: 0.9066
# Epoch 54/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.1718 - accuracy: 0.9292 - val_loss: 0.2880 - val_accuracy: 0.9029
# Epoch 55/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.1609 - accuracy: 0.9340 - val_loss: 0.3450 - val_accuracy: 0.9085
# Epoch 56/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.1663 - accuracy: 0.9317 - val_loss: 0.3311 - val_accuracy: 0.9106
# Epoch 57/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.1640 - accuracy: 0.9344 - val_loss: 0.2679 - val_accuracy: 0.9056
# Epoch 58/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.1558 - accuracy: 0.9369 - val_loss: 0.2565 - val_accuracy: 0.9173
# Epoch 59/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.1527 - accuracy: 0.9381 - val_loss: 0.3172 - val_accuracy: 0.9028
# Epoch 60/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.1417 - accuracy: 0.9443 - val_loss: 0.2824 - val_accuracy: 0.9173
# Epoch 61/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.1405 - accuracy: 0.9426 - val_loss: 0.2999 - val_accuracy: 0.9072
# Epoch 62/100
# 19/19 [==============================] - 10s 537ms/step - loss: 0.1332 - accuracy: 0.9478 - val_loss: 0.2544 - val_accuracy: 0.9111
# Epoch 63/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.1337 - accuracy: 0.9463 - val_loss: 0.2536 - val_accuracy: 0.9208
# Epoch 64/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.1439 - accuracy: 0.9433 - val_loss: 0.2377 - val_accuracy: 0.9127
# Epoch 65/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.1332 - accuracy: 0.9462 - val_loss: 0.3053 - val_accuracy: 0.8767
# Epoch 66/100
# 19/19 [==============================] - 10s 533ms/step - loss: 0.1257 - accuracy: 0.9497 - val_loss: 0.2318 - val_accuracy: 0.9196
# Epoch 67/100
# 19/19 [==============================] - 10s 533ms/step - loss: 0.1229 - accuracy: 0.9510 - val_loss: 0.2945 - val_accuracy: 0.9094
# Epoch 68/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.1215 - accuracy: 0.9509 - val_loss: 0.2499 - val_accuracy: 0.9172
# Epoch 69/100
# 19/19 [==============================] - 10s 548ms/step - loss: 0.1208 - accuracy: 0.9512 - val_loss: 0.2819 - val_accuracy: 0.9116
# Epoch 70/100
# 19/19 [==============================] - 10s 533ms/step - loss: 0.1112 - accuracy: 0.9558 - val_loss: 0.3065 - val_accuracy: 0.9120
# Epoch 71/100
# 19/19 [==============================] - 10s 532ms/step - loss: 0.1100 - accuracy: 0.9559 - val_loss: 0.3120 - val_accuracy: 0.8925
# Epoch 72/100
# 19/19 [==============================] - 10s 546ms/step - loss: 0.1097 - accuracy: 0.9564 - val_loss: 0.2653 - val_accuracy: 0.9167
# Epoch 73/100
# 19/19 [==============================] - 10s 532ms/step - loss: 0.1251 - accuracy: 0.9493 - val_loss: 0.3770 - val_accuracy: 0.8973
# Epoch 74/100
# 19/19 [==============================] - 10s 533ms/step - loss: 0.1268 - accuracy: 0.9486 - val_loss: 0.3424 - val_accuracy: 0.8816
# Epoch 75/100
# 19/19 [==============================] - 10s 532ms/step - loss: 0.1171 - accuracy: 0.9526 - val_loss: 0.3926 - val_accuracy: 0.8879
# Epoch 76/100
# 19/19 [==============================] - 10s 533ms/step - loss: 0.1252 - accuracy: 0.9496 - val_loss: 0.3670 - val_accuracy: 0.8930
# Epoch 77/100
# 19/19 [==============================] - 10s 533ms/step - loss: 0.1095 - accuracy: 0.9561 - val_loss: 0.3048 - val_accuracy: 0.8895
# Epoch 78/100
# 19/19 [==============================] - 10s 533ms/step - loss: 0.1039 - accuracy: 0.9584 - val_loss: 0.3135 - val_accuracy: 0.9005
# Epoch 79/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.1020 - accuracy: 0.9588 - val_loss: 0.2731 - val_accuracy: 0.9138
# Epoch 80/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0975 - accuracy: 0.9607 - val_loss: 0.3396 - val_accuracy: 0.9070
# Epoch 81/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0917 - accuracy: 0.9635 - val_loss: 0.2626 - val_accuracy: 0.9059
# Epoch 82/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0884 - accuracy: 0.9647 - val_loss: 0.3417 - val_accuracy: 0.9045
# Epoch 83/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.0864 - accuracy: 0.9651 - val_loss: 0.3854 - val_accuracy: 0.8944
# Epoch 84/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0848 - accuracy: 0.9661 - val_loss: 0.3720 - val_accuracy: 0.8993
# Epoch 85/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.0888 - accuracy: 0.9643 - val_loss: 0.3537 - val_accuracy: 0.9033
# Epoch 86/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.0853 - accuracy: 0.9662 - val_loss: 0.3809 - val_accuracy: 0.9082
# Epoch 87/100
# 19/19 [==============================] - 10s 536ms/step - loss: 0.0828 - accuracy: 0.9666 - val_loss: 0.4301 - val_accuracy: 0.9104
# Epoch 88/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0840 - accuracy: 0.9661 - val_loss: 0.3952 - val_accuracy: 0.9150
# Epoch 89/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.0816 - accuracy: 0.9671 - val_loss: 0.4058 - val_accuracy: 0.8879
# Epoch 90/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0829 - accuracy: 0.9666 - val_loss: 0.4710 - val_accuracy: 0.8993
# Epoch 91/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0788 - accuracy: 0.9681 - val_loss: 0.4691 - val_accuracy: 0.8977
# Epoch 92/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.0801 - accuracy: 0.9679 - val_loss: 0.3117 - val_accuracy: 0.9207
# Epoch 93/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0776 - accuracy: 0.9690 - val_loss: 0.3226 - val_accuracy: 0.9081
# Epoch 94/100
# 19/19 [==============================] - 10s 533ms/step - loss: 0.0766 - accuracy: 0.9693 - val_loss: 0.3280 - val_accuracy: 0.9157
# Epoch 95/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0732 - accuracy: 0.9707 - val_loss: 0.3007 - val_accuracy: 0.9026
# Epoch 96/100
# 19/19 [==============================] - 10s 533ms/step - loss: 0.0741 - accuracy: 0.9699 - val_loss: 0.4771 - val_accuracy: 0.8999
# Epoch 97/100
# 19/19 [==============================] - 10s 548ms/step - loss: 0.0715 - accuracy: 0.9711 - val_loss: 0.4153 - val_accuracy: 0.9020
# Epoch 98/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0694 - accuracy: 0.9721 - val_loss: 0.4530 - val_accuracy: 0.9182
# Epoch 99/100
# 19/19 [==============================] - 10s 534ms/step - loss: 0.0691 - accuracy: 0.9721 - val_loss: 0.3650 - val_accuracy: 0.9140
# Epoch 100/100
# 19/19 [==============================] - 10s 535ms/step - loss: 0.0713 - accuracy: 0.9709 - val_loss: 0.4812 - val_accuracy: 0.8977

# %%
# plot the training and validation accuracy and loss at each epoch
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "y", label="Training loss")
plt.plot(epochs, val_loss, "r", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs, acc, "y", label="Training acc")
plt.plot(epochs, val_acc, "r", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
